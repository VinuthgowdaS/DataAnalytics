# %% [markdown]
# <a href="https://colab.research.google.com/github/VinuthgowdaS/DataAnalytics/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataset
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.drop(columns="Postal Code", inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State Region  \
# 9989    Second Class  Consumer  United States        Miami     Florida  South
# 9990  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9991  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9992  Standard Class  Consumer  United States   Costa Mesa  California   West
# 9993    Second Class  Consumer  United States  Westminster  California   West
#
#              Category Sub-Category    Sales  Quantity  Discount   Profit
# 9989        Furniture  Furnishings   25.248         3       0.2   4.1028
# 9990        Furniture  Furnishings   91.960         2       0.0  15.6332
# 9991       Technology       Phones  258.576         2       0.2  19.3932
# 9992  Office Supplies        Paper   29.600         4       0.0  13.3200
# 9993  Office Supplies   Appliances  243.160         2       0.0  72.9480

# %%
print(df["Ship Mode"].unique())
print(df["Segment"].unique())
print(df["Country"].unique())
print(df["Category"].unique())
print(df["Sub-Category"].unique())
print(df["Region"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# ['South' 'West' 'Central' 'East']

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Sales anlysis based on region
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Region")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Region")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Region")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Profit"].sum().plot.line()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Quantity"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Quantity'>

# %%
df.groupby("Region")["Discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Discount'>

# %%
df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Segment")["Sales"].sum().plot.pie(autopct="1%.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Segment")["Profit"].sum().plot.pie(autopct="1%.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Segment")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Segment")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Segment")["Quantity"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Segment")["Discount"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Segment")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Segment")["Profit"].sum().plot.line()
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Category")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Category")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Category")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Category")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df.groupby("Region").value_counts()
# Out:
# Region   Ship Mode       Segment      Country        City         State       Postal Code  Category         Sub-Category  Sales    Quantity  Discount  Profit
# Central  Standard Class  Consumer     United States  Detroit      Michigan    48227        Furniture        Chairs        389.970  3         0.0        35.0973     2
#          First Class     Consumer     United States  Houston      Texas       77041        Office Supplies  Paper         47.952   3         0.2        16.1838     2
#          Standard Class  Corporate    United States  Houston      Texas       77041        Office Supplies  Paper         15.552   3         0.2        5.4432      2
#          Second Class    Corporate    United States  Chicago      Illinois    60653        Office Supplies  Binders       3.564    3         0.8       -6.2370      2
#          First Class     Consumer     United States  Abilene      Texas       79605        Office Supplies  Appliances    1.392    2         0.8       -3.7584      1
# ...

# %%
df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Sales"].sum().plot.pie(autopct="1%.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("State")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Sales"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("State")["Profit"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("State")["Quantity"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("State")["Discount"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("State")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("State")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("State")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("State")["Profit"].sum().plot.line()
# Out:
# <Axes: xlabel='State'>

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.pie(autopct="1%.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Sub-Category")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Sub-Category")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.line()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("City")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Quantity"].sum().plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby("City")["Sales"].sum().plot.pie(autopct="1%.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("City")["Sales"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("City")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("City")["Sales"].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
